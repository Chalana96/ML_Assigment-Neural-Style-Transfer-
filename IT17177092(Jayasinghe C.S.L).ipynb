# %% [markdown]
# <a href="https://colab.research.google.com/github/Chalana96/ML_Assigment-Neural-Style-Transfer-/blob/main/IT17177092(Jayasinghe%20C.S.L).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow_hub as hub
import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')

# %%
def load_image(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = img[tf.newaxis, :]
    return img

# %%
from google.colab import files
from io import BytesIO
from PIL import Image

uploaded = files.upload()
im = Image.open(BytesIO(uploaded['profile.JPG']))
# Out:
#      <input type="file" id="files-ccd84ce8-7889-4040-a8cb-d46fdbf968ca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ccd84ce8-7889-4040-a8cb-d46fdbf968ca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving profile.JPG to profile.JPG

# %%
from google.colab import files
from io import BytesIO
from PIL import Image

uploaded = files.upload()
im = Image.open(BytesIO(uploaded['klimt.jpg']))
# Out:
#      <input type="file" id="files-a678dc69-50f7-4dd9-affa-c91f207c85ab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a678dc69-50f7-4dd9-affa-c91f207c85ab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving klimt.jpg to klimt.jpg

# %%
content_image = load_image('profile.JPG')
style_image = load_image('klimt.jpg')

# %%
plt.imshow(np.squeeze(style_image))
plt.show()

# %%
style_image = model(tf.constant(content_image), tf.constant(style_image))[0]

# %%
plt.imshow(np.squeeze(style_image))
plt.show()
